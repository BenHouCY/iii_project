# %%
import requests
import re
urlID=[]
for i in range(10):
    url = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=zh_TW&prettyPrint=false&source=gcsc&gss=.com&sig=01d3e4019d02927b30f1da06094837dc&start={}&cx=partner-pub-2628371516912843:futcqntfmz3&q=%E6%83%A1%E6%88%BF%E6%9D%B1&cse_tok=AHL74MxBGYM-sf7eo4BkS0B0KuNw:1504250420614&filter=0&sort=&googlehost=www.google.com&callback=google.search.Search.apiary11848&nocache=1504250416192'.format(i*10)
    res =requests.get(url)
    text = res.text.split('ogUrl":"')
    for i in range(1,11):
        texx = text[i].split('","ogType')[0]
        #print(texx)
        urlID.append(texx)
len(urlID)
# Out:
# 100

# %%
#FetchAll
#!/usr/bin/python3
# -*- utf8 -*-
#導入PyMySQL庫
import pymysql as mariadb
#測試連接MariaDB數據庫
try:
    conn = mariadb.connect(
        host='db',
        user='root',
        passwd='1234',
        db='rental',
        charset='utf8mb4'
    )
    #設置cursor
    cursor = conn.cursor()
    #撰寫SQL語句
    #sql = "show tables;"
    sql = "select * from traffic; "
    try:
        cursor.execute(sql)
        results = cursor.fetchall()
        for item in results:
            #typeId = item[0]
            #typename = item[1]
            print(item)
    except Exception as e:
        print('Execute Failed!\nError Code is %s;\nError Content is %s;' % (e.args[0],e.args[1]))
    #關閉cursor
    cursor.close()
    #關閉數據庫連接
    conn.close()
except Exception as e:
    print('Connection Failed!\nError Code is %s;\nError Content is %s;' % (e.args[0],e.args[1]))
# Out:
# (31010, '', '台北新光影城', '台北市萬華區西寧南路36號4樓', 305, 0, '', Decimal('25.04524250000000000'), Decimal('121.50649430000000000'), 108)
# (31011, '', '台北信義威秀影城', '台北市信義區松壽路18號2、3樓， 20號3樓', 305, 0, '', Decimal('25.03568390000000000'), Decimal('121.56681000000000000'), 110)
# (31012, '', '台北京站威秀影城', '台北市大同區華陰街34號5、6樓', 305, 0, '', Decimal('25.04954070000000000'), Decimal('121.51804180000000000'), 103)
# (31013, '', '南山大戲院', '台北市通化街24巷1號', 305, 0, '', Decimal('25.03166330000000000'), Decimal('121.55400380000000000'), 106)
# (31014, '', '光點', '台北市中山北路2段18號', 305, 0, '', Decimal('25.05327900000000000'), Decimal('121.52216100000000000'), 104)
# (31015, '', '龍祥百老匯影城', '台北市文山區羅斯福路四段200號3、4、5樓', 305, 0, '', Decimal('25.01091180000000000'), Decimal('121.53665500000000000'), 116)
# (31016, '', '鴻金寶麻吉影城', '新北市新莊區民安路188巷5號4樓', 305, 0, '', Decimal('25.02326900000000000'), Decimal('121.42492700000000000'), 242)
# ...
