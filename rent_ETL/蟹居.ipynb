# %%
import requests
import re
url = 'https://rent.tmm.org.tw/Home/Search?pSearchJson={%22CityRegionRoadSearch%22:%22%E8%87%BA%E5%8C%97%E5%B8%82%22,%22RentalTypeTextSearch%22:%22%E4%BD%8F%E5%AE%B6%22,%22SearchType%22:%221%22}&pFrom=L'

# %%
numb = set()
for i in range(1,20):
    url = 'https://rent.tmm.org.tw/RentSearch/PageIndex'
    page = '{}'.format(i)
    from_data = {'pAddJson':'{"RentSSearch":"","RentESearch":"","LayoutSearch":"","FlatSSearch":"","FlatESearch":"","RentalTypeSearch":"","AttnSearch":"","FloorSSearch":"","FloorESearch":"","SexSearch":"","OtherTenantTypeSearch":"","OtherPetSearch":"","OtherCookSearch":"","OtherCateGoryASearch":"","OtherCateGoryBSearch":"","OtherCateGoryCSearch":"","OtherCateGoryDSearch":"","EquipmentSearch":"","FurnitureSearch":"","Flag":"","FlagType":"1","CityRegionRoadSearch":"臺北市","AreaSearch":"","TrafficSearch":"","StationSearch":"","StationNameSearch":"","SchoolSearch":"","SchoolNameSearch":"","RentalTypeSearch2":"","RentalTypeTextSearch":"","SearchCondition":"","RentalTypeSearch3":""}','pPageIndex':page}
    header = {'Cookie':'_ga=GA1.3.1146491908.1501663771; Font=3USUyGvvZp0Yw4Hk7qHcxsmI_Umxxd2yPGjhSfN3ejGLUEuAKn2WjmE2ku4saf-nSsdRUNJZUFF4D5_V42O0_Bt__7ffoULgt1Pgvw69hY4uKZXy4PZqVbQ-pc_8O3-SdTn6WRRY9tXAvlTBo3TdOZp8d-YqtrM138UiPAaH1bEC-l_-Xwis-gk_qrbK_Wf4t_X5JgpQtKHpKghXO169qdFt-wKYEAPZb5Budq_J1vL0_km7s8QJPV9imE8O4dQyxelaHZCAN_2RIuQIU3E2MuAwskLieaS6boLQrACyn4vqTUOO5_W4f-f8htq06pGwZai1qy50IiKMoKAA9sGJGBDu-HCZDMEvcBfrxcsPLHwF-Y6NUB69D-L_ZbWnlTbf3AlUW1l-CMwf8rqb4eKtKA; Culture=zh-tw; __RequestVerificationToken=V0vovfKjvBnUzeYrVoxrwK3HE-kBCCcK-btH3PF_91zFs7A5SpJtZd3ROLKtO_uBESqENUgwtzNovr6MOZcwo4luffLhObkTKMY-BCqpbD01'}
    res = requests.post(url,data = from_data,headers = header)
    num = re.findall('/RentSearch/GoToDetail\?pRentalNo=(\w+)&',res.text)
    print(i)
    print(res.status_code)
    for j in num :
        numb.add(j)
numb
# Out:
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# {'170200006',
#  '170200022',
#  '170200055',
#  '170300002',
#  '170300006',
#  '170300037',
#  '170300060',
#  '170300062',
#  '170300063',
#  '170300068',
#  '170300140',
#  '170300145',
#  '170300146',
#  '170300148',
#  '170300150',
#  '170300203',
#  '170400131',
#  '170400154',
#  '170400179',
#  '170400181',
#  '170500016',
#  '170500041',
#  '170500143',
#  '170500144',
#  '170500233',
#  '170600039',
#  '170600041',
#  '170600059',
#  '170600097',
#  '170600102',
#  '170600113',
#  '170600114',
#  '170600116',
#  '170600117',
#  '170600143',
#  '170600149',
#  '170600204',
#  '170600224',
#  '170700004',
#  '170700064',
#  '170700067',
#  '170700075',
#  '170700084',
#  '170700094',
#  '170700098',
#  '170700099',
#  '170700101',
#  '170700106',
#  '170700108',
#  '170700115',
# ...

# %%
_ga=GA1.3.1146491908.1501663771; Font=3USUyGvvZp0Yw4Hk7qHcxsmI_Umxxd2yPGjhSfN3ejGLUEuAKn2WjmE2ku4saf-nSsdRUNJZUFF4D5_V42O0_Bt__7ffoULgt1Pgvw69hY4uKZXy4PZqVbQ-pc_8O3-SdTn6WRRY9tXAvlTBo3TdOZp8d-YqtrM138UiPAaH1bEC-l_-Xwis-gk_qrbK_Wf4t_X5JgpQtKHpKghXO169qdFt-wKYEAPZb5Budq_J1vL0_km7s8QJPV9imE8O4dQyxelaHZCAN_2RIuQIU3E2MuAwskLieaS6boLQrACyn4vqTUOO5_W4f-f8htq06pGwZai1qy50IiKMoKAA9sGJGBDu-HCZDMEvcBfrxcsPLHwF-Y6NUB69D-L_ZbWnlTbf3AlUW1l-CMwf8rqb4eKtKA; Culture=zh-tw; __RequestVerificationToken=V0vovfKjvBnUzeYrVoxrwK3HE-kBCCcK-btH3PF_91zFs7A5SpJtZd3ROLKtO_uBESqENUgwtzNovr6MOZcwo4luffLhObkTKMY-BCqpbD01
Host:rent.tmm.org.tw

# %%
for i in range(1,20):
    url = 'https://rent.tmm.org.tw/RentSearch/PageIndex'
    page = '{}'.format(i)
    from_data = {'pAddJson':'{"RentSSearch":"","RentESearch":"","LayoutSearch":"","FlatSSearch":"","FlatESearch":"","RentalTypeSearch":"","AttnSearch":"","FloorSSearch":"","FloorESearch":"","SexSearch":"","OtherTenantTypeSearch":"","OtherPetSearch":"","OtherCookSearch":"","OtherCateGoryASearch":"","OtherCateGoryBSearch":"","OtherCateGoryCSearch":"","OtherCateGoryDSearch":"","EquipmentSearch":"","FurnitureSearch":"","Flag":"","FlagType":"1","CityRegionRoadSearch":"新北市","AreaSearch":"","TrafficSearch":"","StationSearch":"","StationNameSearch":"","SchoolSearch":"","SchoolNameSearch":"","RentalTypeSearch2":"","RentalTypeTextSearch":"","SearchCondition":"","RentalTypeSearch3":""}','pPageIndex':page}
    header = {'Cookie':'_ga=GA1.3.1146491908.1501663771; Font=3USUyGvvZp0Yw4Hk7qHcxsmI_Umxxd2yPGjhSfN3ejGLUEuAKn2WjmE2ku4saf-nSsdRUNJZUFF4D5_V42O0_Bt__7ffoULgt1Pgvw69hY4uKZXy4PZqVbQ-pc_8O3-SdTn6WRRY9tXAvlTBo3TdOZp8d-YqtrM138UiPAaH1bEC-l_-Xwis-gk_qrbK_Wf4t_X5JgpQtKHpKghXO169qdFt-wKYEAPZb5Budq_J1vL0_km7s8QJPV9imE8O4dQyxelaHZCAN_2RIuQIU3E2MuAwskLieaS6boLQrACyn4vqTUOO5_W4f-f8htq06pGwZai1qy50IiKMoKAA9sGJGBDu-HCZDMEvcBfrxcsPLHwF-Y6NUB69D-L_ZbWnlTbf3AlUW1l-CMwf8rqb4eKtKA; Culture=zh-tw; __RequestVerificationToken=V0vovfKjvBnUzeYrVoxrwK3HE-kBCCcK-btH3PF_91zFs7A5SpJtZd3ROLKtO_uBESqENUgwtzNovr6MOZcwo4luffLhObkTKMY-BCqpbD01'}
    res = requests.post(url,data = from_data,headers = header)
    num = re.findall('/RentSearch/GoToDetail\?pRentalNo=(\w+)&',res.text)
    print(i)
    print(res.status_code)
    for j in num :
        numb.add(j)
numb
# Out:
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# {'170200006',
#  '170200009',
#  '170200022',
#  '170200055',
#  '170200056',
#  '170200110',
#  '170300002',
#  '170300006',
#  '170300012',
#  '170300037',
#  '170300060',
#  '170300062',
#  '170300063',
#  '170300068',
#  '170300079',
#  '170300128',
#  '170300137',
#  '170300140',
#  '170300145',
#  '170300146',
#  '170300148',
#  '170300150',
#  '170300188',
#  '170300203',
#  '170300207',
#  '170300208',
#  '170300233',
#  '170300247',
#  '170400047',
#  '170400090',
#  '170400131',
#  '170400154',
#  '170400160',
#  '170400179',
#  '170400181',
#  '170400204',
#  '170500016',
#  '170500041',
#  '170500143',
#  '170500144',
#  '170500182',
#  '170500233',
#  '170500278',
#  '170600007',
#  '170600039',
#  '170600041',
#  '170600048',
#  '170600059',
#  '170600062',
#  '170600072',
# ...

# %%
len(numb)
# Out:
# 161

# %%
import os
with open(os.path.join('D:/crab_living','urlList.txt'),'w',encoding='utf8') as f:
        for i in numb:
            f.write(i+'\n')

# %%
import os
import time
error = 0
sucess = 0
j = 0
for i in numb:
    url = 'https://rent.tmm.org.tw/HouseDetail/Detail01?pRentalNo={}'.format(i)
    header = header = {'Cookie':'_ga=GA1.3.1146491908.1501663771; Font=3USUyGvvZp0Yw4Hk7qHcxsmI_Umxxd2yPGjhSfN3ejGLUEuAKn2WjmE2ku4saf-nSsdRUNJZUFF4D5_V42O0_Bt__7ffoULgt1Pgvw69hY4uKZXy4PZqVbQ-pc_8O3-SdTn6WRRY9tXAvlTBo3TdOZp8d-YqtrM138UiPAaH1bEC-l_-Xwis-gk_qrbK_Wf4t_X5JgpQtKHpKghXO169qdFt-wKYEAPZb5Budq_J1vL0_km7s8QJPV9imE8O4dQyxelaHZCAN_2RIuQIU3E2MuAwskLieaS6boLQrACyn4vqTUOO5_W4f-f8htq06pGwZai1qy50IiKMoKAA9sGJGBDu-HCZDMEvcBfrxcsPLHwF-Y6NUB69D-L_ZbWnlTbf3AlUW1l-CMwf8rqb4eKtKA; Culture=zh-tw; __RequestVerificationToken=V0vovfKjvBnUzeYrVoxrwK3HE-kBCCcK-btH3PF_91zFs7A5SpJtZd3ROLKtO_uBESqENUgwtzNovr6MOZcwo4luffLhObkTKMY-BCqpbD01'}
    j+=1
    #if j/40 == 0:
     #   time.sleep(30)
    try:
        res = requests.get(url,headers=header)
        with open(os.path.join('D:/crab_living','crab_{}.txt'.format(j)),'w',encoding='utf8') as f:
            f.write('url:'+i+'\n')
            f.write('html:'+res.text)
            sucess +=1
    except Exception as e:
            error+=1    
            print(error)
            pass
print(sucess)
# Out:
# 161
