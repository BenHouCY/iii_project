# %%
import requests
import re

# %%
#591 the selecting condition is in cookies, expire in 2 hours
type={}
type['TPE_整層住家']='1'
type['TPE_獨立套房']='2'
type['TPE_分租套房']='3'
type['TPE_雅房']='4'

# %%
#get url pages
def get_url_pages(page,typenum):
    url = 'https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind={}&searchtype=1&region=3&firstRow={}'.format(typenum,page*30)
    header = {}
    header['cookie'] = 'T591_TOKEN=5jpo9dp2u9urvaul3opno1aq20; __gads=ID=54178634ad28a408:T=1502549654:S=ALNI_MYgNARfWpeuSG91dKOKmMhokyAKNQ; loginNoticeNumber=2; c10f3143a018a0513ebe1e8d27b5391c=1; last_search_type=1; PHPSESSID=739u08n9olae23jqmbgb0atbf2; localTime=2; is_new_index=1; is_new_index_redirect=1; index_keyword_search_analysis=%7B%22role%22%3A%221%22%2C%22type%22%3A%221%22%2C%22keyword%22%3A%22%22%2C%22selectKeyword%22%3A%22%22%2C%22menu%22%3A%22%22%2C%22hasHistory%22%3A0%2C%22hasPrompt%22%3A0%2C%22history%22%3A0%7D; new_rent_list_kind_test=0; DETAIL[1][5508575]=1; user_index_role=1; user_browse_recent=a%3A5%3A%7Bi%3A0%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225508575%22%3B%7Di%3A1%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225467550%22%3B%7Di%3A2%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225467238%22%3B%7Di%3A3%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225454324%22%3B%7Di%3A4%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225439482%22%3B%7D%7D; _ga=GA1.3.469437797.1501671866; _gid=GA1.3.470493907.1503300479; __auc=545417a315da2a016f626e47410; ba_cid=a%3A5%3A%7Bs%3A6%3A%22ba_cid%22%3Bs%3A32%3A%2280b87a07b970e12ccbdbfd8249d13a71%22%3Bs%3A7%3A%22page_ex%22%3Bs%3A48%3A%22https%3A%2F%2Frent.591.com.tw%2Frent-detail-5467550.html%22%3Bs%3A4%3A%22page%22%3Bs%3A48%3A%22https%3A%2F%2Frent.591.com.tw%2Frent-detail-5508575.html%22%3Bs%3A7%3A%22time_ex%22%3Bi%3A1503364578%3Bs%3A4%3A%22time%22%3Bi%3A1503370790%3B%7D; ResolutionSort=1; _gat=1; urlJumpIp=1; urlJumpIpByTxt=%E5%8F%B0%E5%8C%97%E5%B8%82; 591_new_session=%3D%3D; _ga=GA1.4.469437797.1501671866; _gid=GA1.4.470493907.1503300479; _gat_UA-97423186-1=1'
    
    #header['referer']='https://rent.591.com.tw/?kind={}&region=1'.format(typenum)
    header['user-agent'] = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
    error = 0
    try:
        res = requests.get(url,headers={'Cookie':header['cookie'],'User-Agent':header['user-agent']})
        #if res.status_code != 200 & error <=3 :
         #   error += 1
         #  print('error')
        #elif error >3:
         #   print("need to be stopped")
    except Exception as e:
        print(e)
    return res

# %%
def get_url(res):
    for urlId in re.findall('\"id\":(\w+)',res.text):
        id_.add(urlId)

# %%
def write_url(rentType):
    with open('D:\\新增資料夾\\url_591_{}.txt'.format(rentType),'w',encoding='utf-8') as f:
        f.write(str(id_))

# %%
totList={}
for rentType,typenum in type.items() :
    print('rentType={}'.format(rentType)) 
    check = True
    page = 0
    id_ = set()

    while check :
        res = get_url_pages(page,typenum)
        print(res.status_code)
        print(page)
        get_url(res)
        check = bool(re.findall('\"id\":(\w+)',res.text))
        print(check)
        page +=1
    print('{}total lists{}'.format(rentType,len(id_)))
    totList[rentType] = list(id_)
    write_url(rentType)
        #get url pages
        #get url
# Out:
# rentType=TPE_整層住家
# 200
# 0
# True
# 200
# 1
# True
# 200
# 2
# True
# 200
# 3
# True
# 200
# 4
# True
# 200
# 5
# True
# 200
# 6
# True
# 200
# 7
# True
# 200
# 8
# True
# 200
# 9
# True
# 200
# 10
# True
# 200
# 11
# True
# 200
# 12
# True
# 200
# 13
# True
# 200
# 14
# True
# 200
# 15
# True
# 200
# 16
# True
# 200
# 17
# True
# 200
# 18
# True
# 200
# 19
# True
# 200
# 20
# True
# 200
# 21
# True
# 200
# 22
# True
# 200
# 23
# True
# 200
# 24
# True
# 200
# 25
# True
# 200
# 26
# True
# 200
# 27
# True
# 200
# 28
# True
# 200
# 29
# True
# 200
# 30
# True
# 200
# 31
# True
# 200
# 32
# True
# 200
# 33
# True
# 200
# 34
# True
# 200
# 35
# True
# 200
# 36
# True
# 200
# 37
# True
# 200
# 38
# True
# 200
# 39
# True
# 200
# 40
# True
# 200
# 41
# True
# 200
# 42
# True
# 200
# 43
# True
# 200
# 44
# True
# 200
# 45
# True
# 200
# 46
# True
# 200
# 47
# True
# 200
# 48
# True
# 200
# 49
# True
# 200
# 50
# True
# 200
# 51
# True
# 200
# 52
# True
# 200
# 53
# True
# 200
# 54
# True
# ...

# %%
# def do_url(page,typenum):
#     res = get_url_pages(page,typenum)
#     print(res.status_code)
    
#     print(page)
#     get_url(res)
#     check = bool(re.findall('\"id\":(\w+)',res.text))
#     print(check)
#     page +=1

# %%
# totList={}
# for rentType,typenum in type.items() :
#     print('rentType={}'.format(rentType)) 
#     check = True
#     page = 0
#     id_ = set()

#     while check :
#         do_url(page,typenum)
#     print('{}total lists{}'.format(rentType,len(id_)))
#     totList[rentType] = list(id_)
#     write_url(rentType)

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#totList

# %%
with open('D:\\新增資料夾\\url_591_whole.txt','w',encoding='utf-8') as f:
    f.write(str(totList))
    f.close

# %%
import requests
import re
import time

# %%
# get deetail index
def get_detail_url(idN):
    url = 'https://rent.591.com.tw/rent-detail-{}.html'.format(idN)
    header = {}
    header['cookie'] = 'T591_TOKEN=5jpo9dp2u9urvaul3opno1aq20; __gads=ID=54178634ad28a408:T=1502549654:S=ALNI_MYgNARfWpeuSG91dKOKmMhokyAKNQ; loginNoticeNumber=2; c10f3143a018a0513ebe1e8d27b5391c=1; last_search_type=1; PHPSESSID=739u08n9olae23jqmbgb0atbf2; localTime=2; is_new_index=1; is_new_index_redirect=1; index_keyword_search_analysis=%7B%22role%22%3A%221%22%2C%22type%22%3A%221%22%2C%22keyword%22%3A%22%22%2C%22selectKeyword%22%3A%22%22%2C%22menu%22%3A%22%22%2C%22hasHistory%22%3A0%2C%22hasPrompt%22%3A0%2C%22history%22%3A0%7D; new_rent_list_kind_test=0; DETAIL[1][5508575]=1; user_index_role=1; user_browse_recent=a%3A5%3A%7Bi%3A0%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225508575%22%3B%7Di%3A1%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225467550%22%3B%7Di%3A2%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225467238%22%3B%7Di%3A3%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225454324%22%3B%7Di%3A4%3Ba%3A2%3A%7Bs%3A4%3A%22type%22%3Bi%3A1%3Bs%3A7%3A%22post_id%22%3Bs%3A7%3A%225439482%22%3B%7D%7D; _ga=GA1.3.469437797.1501671866; _gid=GA1.3.470493907.1503300479; __auc=545417a315da2a016f626e47410; ba_cid=a%3A5%3A%7Bs%3A6%3A%22ba_cid%22%3Bs%3A32%3A%2280b87a07b970e12ccbdbfd8249d13a71%22%3Bs%3A7%3A%22page_ex%22%3Bs%3A48%3A%22https%3A%2F%2Frent.591.com.tw%2Frent-detail-5467550.html%22%3Bs%3A4%3A%22page%22%3Bs%3A48%3A%22https%3A%2F%2Frent.591.com.tw%2Frent-detail-5508575.html%22%3Bs%3A7%3A%22time_ex%22%3Bi%3A1503364578%3Bs%3A4%3A%22time%22%3Bi%3A1503370790%3B%7D; ResolutionSort=1; _gat=1; urlJumpIp=1; urlJumpIpByTxt=%E5%8F%B0%E5%8C%97%E5%B8%82; 591_new_session=%3D%3D; _ga=GA1.4.469437797.1501671866; _gid=GA1.4.470493907.1503300479; _gat_UA-97423186-1=1'
    header['user-agent'] = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
    try:
        res = requests.get(url,headers={'Cookie':header['cookie'],'User-Agent':header['user-agent']})
        #if res.status_code != 200 & error <=3 :
         #   error += 1
         #  print('error')
        #elif error >3:
         #   print("need to be stopped")
    except Exception as e:
        print(e)
    return res

# %%
def make_page(idN,res):
    page={}
    page['url']='https://rent.591.com.tw/rent-detail-{}.html'.format(idN)
    page['html']=res.text
    page['time']=time.strftime("%Y-%m-%d")
    return page

# %%
def write_detail_url(rentType,i,page):
    try:
        with open('D:\\新增資料夾\\{}\\url_591_{}.txt'.format(rentType,i),'w',encoding='utf-8') as f:
            f.write(str(page))
    except Exception as e:
        print(e)

# %%
for rentType,id_ in totList.items() :
    print('rentType={}'.format(rentType)) 
    i=0
    for idN in id_ :
        i += 1
        res = get_detail_url(idN)
        print(res.status_code)
        page = make_page(idN,res)
        write_detail_url(rentType,i,page)
    print('{} go through {}'.format(rentType,i))
# Out:
# rentType=TPE_整層住家
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...
